# %%
import json

# %%
# load json file to extend the node info
with open("../data/aggregated_data.json") as jr:
    cve_json = json.load(jr)

# %%
list(cve_json.keys())
# Out:
# ['org.jenkins-ci.main:cli:1.591',
#  'org.elasticsearch:elasticsearch-hadoop:2.2.0-beta1',
#  'org.jvnet.hudson.main:hudson-core:1.128',
#  'net.sourceforge.htmlunit:neko-htmlunit:2.47.0',
#  'org.jenkins-ci.main:cli:1.592',
#  'org.jvnet.hudson.main:hudson-core:1.129',
#  'net.sourceforge.htmlunit:neko-htmlunit:2.47.1',
#  'org.springframework.boot:spring-boot-actuator:1.2.6.RELEASE',
#  'org.jenkins-ci.main:cli:1.593',
#  'org.jenkins-ci.main:cli:1.594',
#  'org.jvnet.hudson.main:hudson-core:1.124',
#  'org.xwiki.rendering:xwiki-rendering-syntax-xhtml:7.3-milestone-1',
#  'org.jvnet.hudson.main:hudson-core:1.125',
#  'org.jvnet.hudson.main:hudson-core:1.126',
#  'org.jenkins-ci.main:cli:1.590',
#  'org.jvnet.hudson.main:hudson-core:1.127',
#  'org.jvnet.hudson.main:hudson-core:1.120',
#  'org.jvnet.hudson.main:hudson-core:1.121',
#  'org.jvnet.hudson.main:hudson-core:1.122',
#  'org.jvnet.hudson.main:hudson-core:1.123',
#  'org.xwiki.rendering:xwiki-rendering-syntax-xhtml:7.3-rc-1',
#  'org.keycloak:keycloak-parent:3.4.0.Final',
#  'org.jenkins-ci.main:cli:1.588',
#  'org.jenkins-ci.main:cli:1.589',
#  'org.apache.nifi:nifi-web-security:1.8.0',
#  'org.webjars.npm:swagger-ui:2.1.3',
#  'org.webjars.npm:swagger-ui:2.1.4',
#  'org.webjars.npm:swagger-ui:2.1.5',
#  'org.jenkins-ci.main:cli:1.584',
#  'org.jenkins-ci.main:cli:1.585',
#  'org.springframework.boot:spring-boot:1.5.7.RELEASE',
#  'org.jenkins-ci.main:cli:1.586',
#  'org.jenkins-ci.main:cli:1.587',
#  'org.jenkins-ci.plugins:azure-vm-agents:802.vbac7a8a5d5e2',
#  'io.micronaut:micronaut-http-server-netty:1.2.0.RC2',
#  'org.apache.tomcat.embed:tomcat-embed-websocket:10.1.16',
#  'org.jvnet.hudson.main:hudson-core:1.139',
#  'org.apache.tomcat.embed:tomcat-embed-websocket:10.1.17',
#  'org.apache.tomcat.embed:tomcat-embed-websocket:10.1.14',
#  'io.micronaut:micronaut-http-server-netty:1.2.0.RC1',
#  'org.apache.tomcat.embed:tomcat-embed-websocket:10.1.15',
#  'org.apache.tomcat.embed:tomcat-embed-websocket:10.1.12',
#  'org.jvnet.hudson.main:hudson-core:1.135',
#  'org.apache.tomcat.embed:tomcat-embed-websocket:10.1.13',
#  'org.jvnet.hudson.main:hudson-core:1.136',
#  'org.apache.tomcat.embed:tomcat-embed-websocket:10.1.10',
#  'org.jvnet.hudson.main:hudson-core:1.137',
#  'org.apache.tomcat.embed:tomcat-embed-websocket:10.1.11',
#  'org.jvnet.hudson.main:hudson-core:1.138',
#  'com.github.binarywang:weixin-java-common:2.4.3',
#  'org.jvnet.hudson.main:hudson-core:1.131',
#  'org.jvnet.hudson.main:hudson-core:1.132',
#  'com.github.binarywang:weixin-java-common:2.4.1',
#  'org.jvnet.hudson.main:hudson-core:1.133',
#  'com.github.binarywang:weixin-java-common:2.4.2',
#  'org.jvnet.hudson.main:hudson-core:1.134',
#  'org.jboss:jboss-ejb-client:4.0.37.Final',
#  'io.undertow:undertow-core:2.2.1.Final',
#  'com.github.binarywang:weixin-java-common:2.4.0',
#  'org.apache.tomcat.embed:tomcat-embed-websocket:10.1.18',
#  'org.xwiki.rendering:xwiki-rendering-syntax-html:8.2.1',
#  'org.jvnet.hudson.main:hudson-core:1.130',
#  'org.xwiki.rendering:xwiki-rendering-syntax-html:8.2.2',
#  'com.nepxion:discovery:3.38.0',
#  'org.jenkins-ci.main:remoting:3131.vf2b_b_798b_ce99',
#  'org.eclipse.jetty:jetty-servlets:9.4.14.v20181114',
#  'org.jboss.remoting:jboss-remoting:3.1.0.Beta1',
#  'io.undertow:undertow-core:1.3.30.Final',
#  'org.keycloak:keycloak-parent:2.0.0.CR1',
#  'org.jenkins-ci.main:cli:1.599',
#  'org.wildfly.bom:wildfly:24.0.0.SP1',
#  'org.jenkins-ci.main:cli:1.595',
#  'org.jenkins-ci.plugins:sounds:0.5',
#  'org.jenkins-ci.main:cli:1.596',
#  'io.netty:netty-handler:4.1.23.Final',
#  'org.jenkins-ci.main:cli:1.597',
#  'org.jenkins-ci.main:cli:1.598',
#  'org.opensearch.plugin:opensearch-reports-scheduler:2.8.0.0',
#  'org.jvnet.hudson.main:hudson-core:1.106',
#  'org.jvnet.hudson.main:hudson-core:1.107',
#  'org.jvnet.hudson.main:hudson-core:1.108',
#  'org.jvnet.hudson.main:hudson-core:1.109',
#  'org.jvnet.hudson.main:hudson-core:1.102',
#  'org.jvnet.hudson.main:hudson-core:1.103',
#  'org.jvnet.hudson.main:hudson-core:1.104',
#  'org.jvnet.hudson.main:hudson-core:1.105',
#  'org.jvnet.hudson.main:hudson-core:1.100',
#  'org.jvnet.hudson.main:hudson-core:1.101',
#  'org.springframework:spring-beans:5.0.5.RELEASE',
#  'org.jvnet.hudson.main:hudson-core:1.117',
#  'org.jvnet.hudson.main:hudson-core:1.118',
#  'org.jvnet.hudson.main:hudson-core:1.119',
#  'org.jvnet.hudson.main:hudson-core:1.113',
#  'io.netty:netty-codec-http2:4.1.67.Final',
#  'org.jvnet.hudson.main:hudson-core:1.114',
#  'org.jvnet.hudson.main:hudson-core:1.115',
#  'org.jvnet.hudson.main:hudson-core:1.116',
#  'org.jvnet.hudson.main:hudson-core:1.110',
#  'io.quarkus:quarkus-core:3.3.0.CR1',
#  'org.jvnet.hudson.main:hudson-core:1.111',
#  'org.jvnet.hudson.main:hudson-core:1.112',
#  'commons-httpclient:commons-httpclient:3.1-alpha1',
#  'org.springframework.integration:spring-integration-ws:4.0.8.RELEASE',
#  'org.springframework:spring-messaging:5.0.6.RELEASE',
#  'com.graphql-java:graphql-java:0.0.0-2024-06-01T07-58-38-481854e',
#  'com.liferay.portal:com.liferay.portal.kernel:2.125.0',
#  'com.liferay.portal:com.liferay.portal.kernel:2.125.1',
#  'org.wildfly.bom:wildfly:18.0.0.Beta1',
#  'com.ning:async-http-client:1.3.4',
#  'org.wildfly.core:wildfly-controller:2.2.1.CR2',
#  'io.undertow:undertow-servlet:1.3.31.Final',
#  'org.jvnet.hudson.main:hudson-core:1.168',
#  'io.undertow:undertow-core:1.2.11.Final',
#  'org.jvnet.hudson.main:hudson-core:1.169',
#  'org.jvnet.hudson.main:hudson-core:1.164',
#  'org.jvnet.hudson.main:hudson-core:1.165',
#  'org.jvnet.hudson.main:hudson-core:1.166',
#  'org.scala-sbt:sbt:1.6.0-RC2',
#  'io.antmedia:ant-media-server:2.0.0',
#  'org.jvnet.hudson.main:hudson-core:1.167',
#  'com.ning:async-http-client:1.3.2',
#  'org.jvnet.hudson.main:hudson-core:1.160',
#  'com.ning:async-http-client:1.3.3',
#  'ca.uhn.hapi.fhir:org.hl7.fhir.r5:5.3.0',
#  'org.jvnet.hudson.main:hudson-core:1.161',
#  'org.scala-sbt:sbt:1.6.0-RC1',
#  'com.ning:async-http-client:1.3.0',
#  'ca.uhn.hapi.fhir:org.hl7.fhir.r5:5.3.1',
#  'org.jvnet.hudson.main:hudson-core:1.162',
#  'com.ning:async-http-client:1.3.1',
#  'ca.uhn.hapi.fhir:org.hl7.fhir.r5:5.3.2',
#  'org.jvnet.hudson.main:hudson-core:1.163',
#  'ca.uhn.hapi.fhir:org.hl7.fhir.r5:5.3.3',
#  'ca.uhn.hapi.fhir:org.hl7.fhir.r5:5.3.4',
#  'net.sf.mpxj-for-vb:10.0.0',
#  'ca.uhn.hapi.fhir:org.hl7.fhir.r5:5.3.5',
#  'ca.uhn.hapi.fhir:org.hl7.fhir.r5:5.3.6',
#  'org.hibernate:hibernate-core:4.2.10.Final',
#  'org.apache.camel:camel-jira:3.14.7',
#  'ca.uhn.hapi.fhir:org.hl7.fhir.r5:5.3.7',
#  'org.xwiki.commons:xwiki-commons-core:3.2-rc-1',
#  'org.apache.camel:camel-jira:3.14.8',
#  'ca.uhn.hapi.fhir:org.hl7.fhir.r5:5.3.8',
#  'org.apache.camel:camel-jira:3.14.5',
#  'org.xerial:sqlite-jdbc:3.14.2.1',
#  'ca.uhn.hapi.fhir:org.hl7.fhir.r5:5.3.9',
#  'org.apache.camel:camel-jira:3.14.6',
#  'io.quarkus:quarkus-keycloak-authorization:1.7.5.Final',
#  'org.apache.solr:solr-core:6.4.2',
#  'org.apache.solr:solr-core:6.4.0',
#  'org.apache.solr:solr-core:6.4.1',
#  'org.keycloak:keycloak-services:4.0.0.Final',
#  'org.jenkins-ci.plugins:netsparker-cloud-scan:1.1.5',
#  'com.graphql-java:graphql-java:0.0.0-2022-11-11T22-07-02-d1947614',
#  'org.springframework:spring-expression:3.2.14.RELEASE',
#  'org.jenkins-ci.plugins:netsparker-cloud-scan:1.1.0',
#  'org.jvnet.hudson.main:hudson-core:1.179',
#  'org.jenkins-ci.plugins:netsparker-cloud-scan:1.1.1',
#  'org.jenkins-ci.plugins:netsparker-cloud-scan:1.1.2',
#  'org.jenkins-ci.plugins:netsparker-cloud-scan:1.1.3',
#  'org.apache.camel:camel-jira:3.14.3',
#  'org.jvnet.hudson.main:hudson-core:1.175',
#  'org.apache.camel:camel-jira:3.14.4',
#  'org.jvnet.hudson.main:hudson-core:1.176',
#  'org.apache.camel:camel-jira:3.14.1',
#  'org.jvnet.hudson.main:hudson-core:1.177',
#  'net.sf.mpxj-for-vb:10.0.5',
#  'org.infinispan:infinispan-server-core:7.2.0.CR1',
#  'org.apache.camel:camel-jira:3.14.2',
#  'org.jvnet.hudson.main:hudson-core:1.178',
#  'org.jvnet.hudson.main:hudson-core:1.171',
#  'net.sf.mpxj-for-vb:10.0.3',
#  'org.apache.camel:camel-jira:3.14.0',
#  'org.jvnet.hudson.main:hudson-core:1.172',
#  'net.sf.mpxj-for-vb:10.0.4',
#  'org.jvnet.hudson.main:hudson-core:1.173',
#  'net.sf.mpxj-for-vb:10.0.1',
#  'org.jvnet.hudson.main:hudson-core:1.174',
#  'net.sf.mpxj-for-vb:10.0.2',
#  'net.sf.mpxj-for-vb:5.2.0',
#  'org.eclipse.jetty:jetty-servlets:9.1.2.v20140210',
#  'org.jvnet.hudson.main:hudson-core:1.170',
#  'org.apache.jackrabbit:jackrabbit-webapp:2.13.0',
#  'org.apache.jackrabbit:jackrabbit-webapp:2.13.1',
#  'org.apache.jackrabbit:jackrabbit-webapp:2.13.2',
#  'org.apache.jackrabbit:jackrabbit-webapp:2.13.3',
#  'org.apache.jackrabbit:jackrabbit-webapp:2.13.4',
#  'org.apache.jackrabbit:jackrabbit-webapp:2.13.5',
#  'org.apache.jackrabbit:jackrabbit-webapp:2.13.6',
#  'org.apache.jackrabbit:jackrabbit-webapp:2.13.7',
#  'org.wildfly.core:wildfly-controller:2.2.1.CR1',
#  'org.jenkins-ci.plugins:git:2.4.1',
#  'org.jenkins-ci.plugins:git:2.4.2',
#  'com.guicedee.services:log4j-core:1.0.8.12-jre12',
#  'org.webjars.bower:angular:1.5.10',
#  'org.jenkins-ci.plugins:git:2.4.0',
#  'com.guicedee.services:log4j-core:1.0.8.12-jre14',
#  'org.webjars.bower:angular:1.5.11',
#  'org.picketlink:picketlink-tomcat-common:2.1.1.Final',
#  'org.keycloak:keycloak-parent:20.0.5',
#  'org.csanchez.jenkins.plugins:kubernetes:1.21.5',
#  'org.jvnet.hudson.main:hudson-core:1.146',
#  'org.csanchez.jenkins.plugins:kubernetes:1.21.6',
#  'org.jvnet.hudson.main:hudson-core:1.147',
#  'org.eclipse.jgit:org.eclipse.jgit:5.11.0.202103091610-r',
#  'org.jenkins-ci.plugins:git:2.4.3',
#  'org.keycloak:keycloak-parent:20.0.3',
#  'org.jvnet.hudson.main:hudson-core:1.148',
#  'org.jenkins-ci.plugins:git:2.4.4',
#  'org.keycloak:keycloak-parent:20.0.4',
#  'org.jvnet.hudson.main:hudson-core:1.149',
#  'org.keycloak:keycloak-parent:20.0.1',
#  'org.csanchez.jenkins.plugins:kubernetes:1.21.1',
#  'org.jvnet.hudson.main:hudson-core:1.142',
#  'org.keycloak:keycloak-parent:20.0.2',
#  'org.csanchez.jenkins.plugins:kubernetes:1.21.2',
#  'org.jvnet.hudson.main:hudson-core:1.143',
#  'org.csanchez.jenkins.plugins:kubernetes:1.21.3',
#  'org.jvnet.hudson.main:hudson-core:1.144',
#  'org.xwiki.rendering:xwiki-rendering-syntax-html:9.8-rc-1',
#  'org.keycloak:keycloak-parent:20.0.0',
#  'org.csanchez.jenkins.plugins:kubernetes:1.21.4',
#  'org.jvnet.hudson.main:hudson-core:1.145',
#  'org.jvnet.hudson.main:hudson-core:1.140',
#  'net.sf.mpxj-for-vb:5.2.1',
#  'org.csanchez.jenkins.plugins:kubernetes:1.21.0',
#  'org.jvnet.hudson.main:hudson-core:1.141',
#  'net.sf.mpxj-for-vb:5.2.2',
#  'org.quartz-scheduler:quartz:1.7.2',
#  'org.quartz-scheduler:quartz:1.7.3',
#  'com.amazonaws:aws-encryption-sdk-java:1.5.0',
#  'org.springframework.data:spring-data-jpa:2.1.1.RELEASE',
#  'io.undertow:undertow-servlet:1.4.0.CR4',
#  'org.springframework.boot:spring-boot-starter-webflux:2.4.12',
#  'org.springframework.boot:spring-boot-starter-webflux:2.4.13',
#  'org.springframework.boot:spring-boot-starter-webflux:2.4.10',
#  'org.springframework.boot:spring-boot-starter-webflux:2.4.11',
#  'net.sf.mpxj:mpxj:8.4.0',
#  'org.wso2.carbon.identity.framework:org.wso2.carbon.identity.application.authentication.framework:5.14.107',
#  'org.wso2.carbon.identity.framework:org.wso2.carbon.identity.application.authentication.framework:5.14.108',
#  'com.netflix.hollow:hollow:4.7.0',
#  'org.wso2.carbon.identity.framework:org.wso2.carbon.identity.application.authentication.framework:5.14.105',
#  'com.netflix.hollow:hollow:4.7.1',
#  'org.wso2.carbon.identity.framework:org.wso2.carbon.identity.application.authentication.framework:5.14.106',
#  'org.jvnet.hudson.main:hudson-core:1.157',
#  'org.wso2.carbon.identity.framework:org.wso2.carbon.identity.application.authentication.framework:5.14.103',
#  'org.jenkins-ci.plugins:pipeline-maven:3.4.0-beta-1',
#  'org.jvnet.hudson.main:hudson-core:1.158',
#  'org.wso2.carbon.identity.framework:org.wso2.carbon.identity.application.authentication.framework:5.14.104',
#  'org.jvnet.hudson.main:hudson-core:1.159',
#  'org.wso2.carbon.identity.framework:org.wso2.carbon.identity.application.authentication.framework:5.14.101',
#  'org.wso2.carbon.identity.framework:org.wso2.carbon.identity.application.authentication.framework:5.14.102',
#  'org.jenkins-ci.plugins:git:2.2.12',
#  'org.rundeck:rundeck-core:2.8.0',
#  'org.jvnet.hudson.main:hudson-core:1.153',
#  'com.netflix.hollow:hollow:4.7.6',
#  'io.undertow:undertow-servlet:1.4.0.CR2',
#  'com.xnx3.wangmarket:wangmarket:5.6.17',
#  'org.rundeck:rundeck-core:2.8.1',
#  'org.jvnet.hudson.main:hudson-core:1.154',
#  'com.netflix.hollow:hollow:4.7.7',
#  'io.undertow:undertow-servlet:1.4.0.CR3',
#  'org.jenkins-ci.plugins:git:2.2.10',
#  'org.rundeck:rundeck-core:2.8.2',
#  'org.jvnet.hudson.main:hudson-core:1.155',
#  'com.netflix.hollow:hollow:4.7.8',
#  'org.jenkins-ci.plugins:git:2.2.11',
#  'org.rundeck:rundeck-core:2.8.3',
#  'org.jenkins-ci.plugins:build-monitor-plugin:1.8+build.201601052013',
#  'org.jvnet.hudson.main:hudson-core:1.156',
#  'com.netflix.hollow:hollow:4.7.9',
#  'io.undertow:undertow-servlet:1.4.0.CR1',
#  'com.xnx3.wangmarket:wangmarket:5.6.12',
#  'org.xwiki.commons:xwiki-commons-xml:11.0.3',
#  'com.netflix.hollow:hollow:4.7.2',
#  'org.jvnet.hudson.main:hudson-core:1.150',
#  'com.netflix.hollow:hollow:4.7.3',
#  'org.xwiki.commons:xwiki-commons-xml:11.0.1',
#  'org.jvnet.hudson.main:hudson-core:1.151',
#  'com.netflix.hollow:hollow:4.7.4',
#  'org.wso2.carbon.identity.framework:org.wso2.carbon.identity.application.authentication.framework:5.14.109',
#  'org.xwiki.commons:xwiki-commons-xml:11.0.2',
#  'org.jvnet.hudson.main:hudson-core:1.152',
#  'com.netflix.hollow:hollow:4.7.5',
#  'io.hawt:project:1.3.0',
#  'org.rundeck:rundeck-core:2.8.4',
#  'org.picketlink:picketlink-tomcat-common:2.7.0.Beta1',
#  'io.hawt:project:1.3.1',
#  'org.picketlink:picketlink-tomcat-common:2.7.0.Beta2',
#  'org.wso2.carbon.identity.framework:org.wso2.carbon.identity.application.authentication.framework:5.14.100',
#  'org.csanchez.jenkins.plugins:kubernetes:3622.va_9dc5592b_10c',
#  'org.eclipse.jetty:jetty-servlets:9.2.9.v20150224',
#  'org.eclipse.jetty:jetty-openid:9.4.46.v20220331',
#  'org.apache.cassandra:apache-cassandra:1.2.17',
#  'org.apache.cassandra:apache-cassandra:1.2.18',
#  'org.apache.cassandra:apache-cassandra:1.2.19',
#  'ca.uhn.hapi.fhir:org.hl7.fhir.dstu3:6.0.22.1',
#  'io.jenkins.plugins:atlassian-bitbucket-server-integration:1.0-beta-4',
#  'ca.uhn.hapi.fhir:org.hl7.fhir.dstu3:6.0.22.2',
#  'io.jenkins.plugins:atlassian-bitbucket-server-integration:1.0-beta-5',
#  'org.jenkins-ci.main:remoting:2.59.1',
#  'io.jenkins.plugins:atlassian-bitbucket-server-integration:1.0-beta-2',
#  'org.jenkins-ci.main:remoting:2.59.2',
#  'org.apache.pinot:pinot:0.1.0',
#  'io.jenkins.plugins:atlassian-bitbucket-server-integration:1.0-beta-3',
#  'org.apache.cassandra:apache-cassandra:1.2.10',
#  'org.jgroups:jgroups:3.1.0.Beta1',
#  'org.drools:drools-core:7.4.1.Final',
#  'org.apache.cassandra:apache-cassandra:1.2.11',
#  'org.apache.cassandra:apache-cassandra:1.2.12',
#  'org.apache.cassandra:apache-cassandra:1.2.13',
#  'org.jenkins-ci.plugins:ontrack:2.13.0',
#  'org.apache.cassandra:apache-cassandra:1.2.14',
#  'org.apache.cassandra:apache-cassandra:1.2.15',
#  'org.apache.cassandra:apache-cassandra:1.2.16',
#  'com.netflix.hollow:hollow:5.1.1',
#  'com.netflix.hollow:hollow:5.1.2',
#  'io.undertow:undertow-servlet:1.4.13.Final',
#  'org.jenkins-ci.plugins:ontrack:2.13.1',
#  'org.jenkins-ci.plugins:ontrack:2.13.2',
#  'com.netflix.hollow:hollow:5.1.0',
#  'org.sonarsource.sonarqube:sonar-plugin-api:6.2-RC3',
#  'org.springframework.security:spring-security-bom:5.2.8.RELEASE',
#  'com.netflix.hollow:hollow:5.1.3',
#  'io.jenkins.plugins:atlassian-bitbucket-server-integration:1.0-beta-1',
#  'org.sonarsource.sonarqube:sonar-plugin-api:6.2-RC1',
#  'org.wildfly.core:wildfly-server:1.0.0.CR7',
#  'org.eclipse.jetty.http2:http2-common:9.3.12.v20160915',
#  'org.jenkins-ci.plugins:cloudbees-bitbucket-branch-source:796.v6cb_1559e1673',
#  'org.apereo.cas:cas-server-support-oidc:6.0.8.1',
#  'org.wildfly.core:wildfly-server:1.0.0.CR1',
#  'org.jenkins-ci.plugins:scriptler:2.4.1',
#  'org.wildfly.core:wildfly-server:1.0.0.CR2',
#  'io.netty:netty-handler:4.1.60.Final',
#  'org.wildfly.core:wildfly-server:1.0.0.CR5',
#  'org.wildfly.core:wildfly-server:1.0.0.CR6',
#  'org.wildfly.core:wildfly-server:1.0.0.CR3',
#  'org.wildfly.core:wildfly-server:1.0.0.CR4',
#  'org.springframework.boot:spring-boot-autoconfigure:1.0.1.RELEASE',
#  'io.gitlab.arturbosch.detekt:detekt-core:1.10.0-RC1',
#  'commons-httpclient:commons-httpclient:3.1-beta1',
#  'org.apache-extras.beanshell:bsh:2.0b5',
#  'org.jboss.xnio:xnio-api:3.7.3.Final',
#  'io.quarkus:quarkus-core:1.11.0.Beta1',
#  'io.quarkus:quarkus-vertx-http:1.8.1.Final',
#  'io.quarkus:quarkus-core:1.11.0.Beta2',
#  'com.graphql-java:graphql-java:0.0.0-2021-12-06T01-22-19-5108111b',
#  'org.wildfly:wildfly-dist:16.0.0.Final',
#  'com.github.shyiko.ktlint:ktlint-core:0.12.0',
#  'com.github.shyiko.ktlint:ktlint-core:0.12.1',
#  'org.springframework.security:spring-security-cas:3.1.0.RELEASE',
#  'org.eclipse.jetty:jetty-http:8.1.12.v20130726',
#  'org.springframework:spring-expression:4.1.7.RELEASE',
#  'org.apache.solr:solr-parent:4.1.0',
#  'org.apache.helix:helix-rest:0.9.10',
#  'org.xwiki.rendering:xwiki-rendering-macro-footnotes:9.11-rc-1',
#  'org.apache.heron:heron-api:0.20.0-incubating',
#  'org.springframework:spring-core:6.0.15',
#  'org.jboss:jboss-ejb-client:1.0.31.Final',
#  'org.jenkins-ci.plugins:aws-beanstalk-publisher-plugin:1.5.3',
#  'org.jenkins-ci.plugins:aws-beanstalk-publisher-plugin:1.5.4',
#  'org.jenkins-ci.plugins:aws-beanstalk-publisher-plugin:1.5.1',
#  'org.jenkins-ci.plugins:aws-beanstalk-publisher-plugin:1.5.2',
#  'org.sonatype.nexus:nexus-core:2.12.1-01',
#  'org.xwiki.commons:xwiki-commons-core:4.1.4',
#  'org.xwiki.commons:xwiki-commons-core:4.1.2',
#  'org.xwiki.commons:xwiki-commons-core:4.1.3',
#  'org.jenkins-ci.plugins:swarm-client:1.6',
#  'org.jenkins-ci.plugins:swarm-client:1.7',
#  'org.xwiki.commons:xwiki-commons-core:4.1.1',
#  'org.jenkins-ci.plugins:swarm-client:1.8',
#  'org.jenkins-ci.plugins:aws-beanstalk-publisher-plugin:1.5.5',
#  'org.jenkins-ci.plugins:swarm-client:1.9',
#  'org.jenkins-ci.plugins:aws-beanstalk-publisher-plugin:1.5.6',
#  'us.springett:alpine:1.4.2',
#  'us.springett:alpine:1.4.3',
#  'us.springett:alpine:1.4.0',
#  'us.springett:alpine:1.4.1',
#  'org.jenkins-ci.plugins:mesos:0.10.1',
#  'org.jetbrains.kotlin:kotlin-stdlib:1.1.3-2',
#  'org.jenkins-ci.plugins:mesos:0.10.0',
#  'org.springframework:spring-expression:4.2.1.RELEASE',
#  'com.mabl.integration.jenkins:mabl-integration:0.0.8',
#  'com.mabl.integration.jenkins:mabl-integration:0.0.9',
#  'org.jenkins-ci.plugins:translation:1.10',
#  'org.apache.calcite:calcite-core:1.24.0',
#  'org.jenkins-ci.plugins:translation:1.11',
#  'org.eclipse.platform:org.eclipse.ui.forms:3.8.0',
#  'io.netty:netty-all:4.1.23.Final',
#  'org.apache.openmeetings:openmeetings-db:6.2.0',
#  'org.xwiki.commons:xwiki-commons-xml:9.8.1',
#  'org.jenkins-ci.plugins:nomad:0.7.0',
#  'org.springframework.cloud:spring-cloud-netflix-zuul:2.2.4.RELEASE',
#  'org.jenkins-ci.plugins:translation:1.12',
#  'com.mabl.integration.jenkins:mabl-integration:0.0.5',
#  'com.mabl.integration.jenkins:mabl-integration:0.0.6',
#  'org.webjars.npm:lite-server:2.1.0',
#  'org.jenkins-ci.plugins:translation:1.14',
#  'com.mabl.integration.jenkins:mabl-integration:0.0.7',
#  'org.springframework:spring-core:5.2.9.RELEASE',
#  'org.jenkins-ci.plugins:translation:1.15',
#  'io.antmedia:ant-media-server:1.6.2',
#  'org.jvnet.hudson.plugins:android-lint:2.0.1',
#  'grpc:1.40.0.pre1',
#  'org.jvnet.hudson.plugins:android-lint:2.0.2',
#  'io.antmedia:ant-media-server:1.6.0',
#  'org.jvnet.hudson.plugins:android-lint:2.0.3',
#  'io.antmedia:ant-media-server:1.6.1',
#  'org.jbpm:jbpm-bpmn2:5.1.0.CR1',
#  'org.jenkins-ci.plugins:nomad:0.7.1',
#  'io.quarkus:quarkus-vertx-http:1.13.0.Final',
#  'org.jenkins-ci.plugins:nomad:0.7.4',
#  'com.guicedee.services:log4j-core:1.0.18.0',
#  'com.guicedee.services:log4j-core:1.0.18.1',
#  'org.apache.atlas:atlas-common:0.6-incubating',
#  'com.google.oauth-client:google-oauth-client:1.26.0',
#  'com.upokecenter:cbor:3.1.0',
#  'org.glassfish.main.orb:orb-connector:5.1.0-RC1',
#  'org.glassfish.main.orb:orb-connector:5.1.0-RC2',
#  'org.jenkins-ci.plugins:git:2.6.2-beta-1',
#  'org.jenkins-ci.plugins:git:2.6.2-beta-2',
#  'org.apache.helix:helix-core:0.6.2-incubating',
#  'io.quarkus:quarkus-kubernetes-deployment:3.4.0.CR1',
#  'org.springframework.data:spring-data-jpa:1.11.14.RELEASE',
#  'org.eclipse.jetty:jetty-server:7.6.3.v20120416',
#  'org.jboss.weld:weld-core-bom:2.2.5.Final',
#  'org.jboss:jboss-ejb-client:2.1.0.Final',
#  'io.strimzi:strimzi:0.39.0',
#  'org.xwiki.commons:xwiki-commons-xml:10.6.1',
#  'com.squareup:connect:2.2.1',
#  'org.jenkins-ci.plugins:ghprb:1.22.3',
#  'org.wildfly:wildfly-parent:23.0.1.Final',
#  'org.jenkins-ci.plugins:ghprb:1.22.4',
#  'org.jenkins-ci.plugins:ghprb:1.22.1',
#  'org.jenkins-ci.plugins:ghprb:1.22.2',
#  'com.squareup:connect:2.2.0',
#  'com.guicedee.services:log4j-core:1.0.19.0',
#  'org.openapitools:openapi-generator:4.3.0',
#  'com.guicedee.services:log4j-core:1.0.19.1',
#  'org.openapitools:openapi-generator:4.3.1',
#  'com.guicedee.services:log4j-core:1.0.19.2',
#  'com.guicedee.services:log4j-core:1.0.19.3',
#  'com.guicedee.services:log4j-core:1.0.19.4',
#  'org.apache.hadoop:hadoop-yarn-server-common:3.2.0',
#  'org.jenkins-ci.plugins:xfpanel:2.0.1',
#  'org.apache.hadoop:hadoop-yarn-server-common:3.2.1',
#  'org.jgroups:jgroups:2.10.0.CR1',
#  'org.apache.hadoop:hadoop-yarn-server-common:3.2.2',
#  'org.apache.uima:uima-ducc-web:2.2.0',
#  'org.jenkins-ci.plugins:xfpanel:2.0.0',
#  'org.springframework.security:spring-security-bom:5.0.16.RELEASE',
#  'org.wildfly.core:wildfly-host-controller:3.0.1.Final',
#  'org.jenkins-ci.plugins:azure-keyvault:123.v1aba71c2d365',
#  'google/protobuf:v3.7.0-rc.3',
#  'io.quarkus:quarkus-core:2.16.1.Final',
#  'com.guicedee.services:log4j-core:1.0.19.5',
#  'pubnub:4.2.4',
#  'com.guicedee.services:log4j-core:1.0.19.6',
#  'pubnub:4.2.5',
#  'pubnub:4.2.2',
#  'pubnub:4.2.3',
#  'com.guicedee.services:log4j-core:1.0.19.9',
#  'pubnub:4.2.6',
#  'pubnub:4.2.7',
#  'org.wildfly.core:wildfly-core-parent:11.0.0.Beta6',
#  'org.wildfly.core:wildfly-core-parent:11.0.0.Beta7',
#  'com.guicedee.services:log4j-core:1.0.8.5-jre13',
#  'org.wildfly.core:wildfly-core-parent:11.0.0.Beta4',
#  'com.guicedee.services:log4j-core:1.0.8.5-jre14',
#  'org.wildfly.core:wildfly-core-parent:11.0.0.Beta5',
#  'org.wildfly.core:wildfly-core-parent:11.0.0.Beta2',
#  'pubnub:4.2.0',
#  'org.wildfly.core:wildfly-core-parent:11.0.0.Beta3',
#  'pubnub:4.2.1',
#  'org.wildfly.core:wildfly-core-parent:11.0.0.Beta1',
#  'org.apache.camel:camel:2.15.2',
#  'org.apache.camel:camel:2.15.3',
#  'io.strimzi:strimzi:0.38.0',
#  'org.apache.camel:camel:2.15.0',
#  'org.apache.camel:camel:2.15.1',
#  'com.typesafe.akka:akka-http-core_2.13:10.5.2',
#  'org.apache.camel:camel:2.15.6',
#  'com.typesafe.akka:akka-http-core_2.13:10.5.0',
#  'org.apache.camel:camel:2.15.4',
#  'com.typesafe.akka:akka-http-core_2.13:10.5.1',
#  'org.apache.camel:camel:2.15.5',
#  'io.apiman:apiman-distro-vertx:1.5.2.Final',
#  'com.hazelcast:hazelcast:1.9.3-RC',
#  'org.springframework.cloud:spring-cloud-function-parent:3.0.14.RELEASE',
#  'org.drools:drools-core:6.3.0.Final',
#  'org.jboss.resteasy:resteasy-jaxb-provider:2.2-beta-1',
#  'com.guicedee.services:log4j-core:1.0.8.5-jre12',
#  'org.http4s:blaze-core_2.11:0.9.0',
#  'org.mortbay.jetty:jetty:6.1.0rc2',
#  'org.wildfly.core:wildfly-core-parent:11.0.0.Beta8',
#  'org.mortbay.jetty:jetty:6.1.0rc3',
#  'org.wildfly.core:wildfly-core-parent:11.0.0.Beta9',
#  'org.springframework:spring-core:3.1.0.RELEASE',
#  'org.wildfly.core:wildfly-server:11.1.0.Final',
#  'ch.qos.logback:logback-core:1.0.10',
#  'ch.qos.logback:logback-core:1.0.11',
#  'org.xwiki.rendering:xwiki-rendering-syntax-annotatedhtml5:7.3',
#  'org.xwiki.rendering:xwiki-rendering-syntax-annotatedhtml5:7.4',
#  'ch.qos.logback:logback-core:1.0.12',
#  'org.xwiki.rendering:xwiki-rendering-syntax-annotatedhtml5:7.1',
#  'ch.qos.logback:logback-core:1.0.13',
#  'org.xwiki.rendering:xwiki-rendering-syntax-annotatedhtml5:7.2',
#  'org.xwiki.rendering:xwiki-rendering-syntax-annotatedhtml5:7.0',
#  'org.springframework.social:spring-social-core:1.0.0.RELEASE',
#  'org.springframework:spring-framework-bom:4.3.14.RELEASE',
#  'org.jboss.xnio:xnio-api:3.8.9.Final',
#  'org.xwiki.commons:xwiki-commons-xml:10.10-rc-1',
#  'org.webjars.npm:lite-server:2.2.0',
#  'io.antmedia:ant-media-server:1.7.1',
#  'org.jenkins-ci.plugins:cobertura:1.12',
#  'io.antmedia:ant-media-server:1.7.2',
#  'org.jenkins-ci.plugins:cobertura:1.13',
#  'org.jenkins-ci.plugins:cobertura:1.10',
#  'io.antmedia:ant-media-server:1.7.0',
#  'org.jenkins-ci.plugins:cobertura:1.11',
#  'org.scala-lang:scala-compiler:2.7.4.final',
#  'org.keycloak:keycloak-saml-core:4.8.2.Final',
#  'org.elasticsearch:elasticsearch:0.12.0',
#  'org.jboss.resteasy:resteasy-core:4.4.2.Final',
#  'org.elasticsearch:elasticsearch:0.12.1',
#  'org.springframework:spring-webflux:5.0.1.RELEASE',
#  'org.jenkins-ci.plugins:cobertura:1.14',
#  'org.jenkins-ci.plugins:cobertura:1.15',
#  'com.erudika:para-core:1.36.0',
#  'com.erudika:para-core:1.36.1',
#  'io.netty:netty-codec-http:4.0.17.Final',
#  'com.linecorp.armeria:armeria:0.74.0',
#  'com.linecorp.armeria:armeria:0.74.1',
#  'org.wso2.carbon.event-processing:org.wso2.carbon.event.processor.core:2.1.10',
#  'org.apache.struts:struts2-parent:2.3.15.1',
#  'org.wso2.carbon.event-processing:org.wso2.carbon.event.processor.core:2.1.17',
#  'org.wso2.carbon.event-processing:org.wso2.carbon.event.processor.core:2.1.18',
#  'org.apache.struts:struts2-parent:2.3.15.2',
#  'org.wso2.carbon.event-processing:org.wso2.carbon.event.processor.core:2.1.15',
#  'org.apache.struts:struts2-parent:2.3.15.3',
#  'org.wso2.carbon.event-processing:org.wso2.carbon.event.processor.core:2.1.16',
#  'org.wso2.carbon.event-processing:org.wso2.carbon.event.processor.core:2.1.13',
#  'org.apache.struts.xwork:xwork-core:2.2.1.1',
#  'io.projectreactor.netty:reactor-netty:0.8.8.RELEASE',
#  'org.wso2.carbon.event-processing:org.wso2.carbon.event.processor.core:2.1.14',
#  'org.eclipse.jetty:jetty-webapp:9.3.8.RC0',
#  'org.wso2.carbon.event-processing:org.wso2.carbon.event.processor.core:2.1.11',
#  'org.wso2.carbon.event-processing:org.wso2.carbon.event.processor.core:2.1.12',
#  'org.wso2.carbon.event-processing:org.wso2.carbon.event.processor.core:2.1.19',
#  'io.undertow:undertow-parent:1.3.23.Final',
#  'ro.pippo:pippo-fastjson:1.7.0',
#  'org.infinispan:infinispan-server-core:5.2.2.Final',
#  'org.drools:drools-core:5.3.4.Final',
#  'org.xwiki.rendering:xwiki-rendering-macro-footnotes:12.5.1',
#  'org.apache.calcite.avatica:avatica-core:1.16.0',
#  'org.jboss.weld:weld-core-bom:1.1.34.Final',
#  'org.apache.inlong:inlong-common:0.12.0-incubating',
#  'org.xwiki.commons:xwiki-commons-velocity:4.3-rc-1',
#  'com.alibaba:dubbo:2.5.10',
#  'com.google.protobuf:protobuf-kotlin-lite:3.18.0-rc-2',
#  'com.liferay.portal:com.liferay.portal.kernel:3.124.0',
#  'com.google.protobuf:protobuf-kotlin-lite:3.18.0-rc-1',
#  'org.eclipse.jetty:jetty-server:7.6.8.v20121106',
#  'org.apache.uima:uima-ducc-web:2.2.1',
#  'org.apache.jackrabbit:jackrabbit-webapp:2.5.1',
#  'org.apache.uima:uima-ducc-web:2.2.2',
#  'org.apache.jackrabbit:jackrabbit-webapp:2.5.2',
#  'org.springframework:spring-framework-bom:4.2.4.RELEASE',
#  'org.xwiki.commons:xwiki-commons-xml:4.5-rc-1',
#  'org.apache.jackrabbit:jackrabbit-webapp:2.5.3',
#  'org.apache.jackrabbit:jackrabbit-webapp:2.5.0',
#  'org.keycloak:keycloak-common:2.5.4.Final',
#  'io.quarkus:quarkus-oidc:2.2.4.Final',
#  'org.jenkins-ci.plugins:git:2.5.0',
#  'org.jenkins-ci.plugins:git:2.5.1',
#  'org.apache.karaf:apache-karaf:4.3.0',
#  'org.apache.karaf:apache-karaf:4.3.1',
#  'org.apache.karaf:apache-karaf:4.3.2',
#  'pubnub:3.8.5',
#  'org.drools:drools-core:7.28.0.Final',
#  'org.apache.karaf:apache-karaf:4.3.3',
#  'org.jenkins-ci.plugins:git:2.5.2',
#  'org.apache.karaf:apache-karaf:4.3.4',
#  'org.jenkins-ci.plugins:git:2.5.3',
#  'org.apache.karaf:apache-karaf:4.3.5',
#  'org.apache.karaf:apache-karaf:4.3.6',
#  'ca.uhn.hapi.fhir:org.hl7.fhir.r4:5.4.5',
#  'pubnub:3.8.1',
#  'org.springframework.boot:spring-boot-autoconfigure:2.3.4.RELEASE',
#  'org.apache.karaf:apache-karaf:4.3.7',
#  'ca.uhn.hapi.fhir:org.hl7.fhir.r4:5.4.6',
#  'pubnub:3.8.2',
#  'ca.uhn.hapi.fhir:org.hl7.fhir.r4:5.4.3',
#  'pubnub:3.8.3',
#  'ca.uhn.hapi.fhir:org.hl7.fhir.r4:5.4.4',
#  'pubnub:3.8.4',
#  'ca.uhn.hapi.fhir:org.hl7.fhir.r4:5.4.9',
#  'ca.uhn.hapi.fhir:org.hl7.fhir.r4:5.4.7',
#  'ca.uhn.hapi.fhir:org.hl7.fhir.r4:5.4.8',
#  'pubnub:3.8.0',
#  'org.jenkins-ci.main:cli:1.508',
#  'org.apache.hadoop:hadoop-yarn-server-common:2.8.5',
#  'org.jenkins-ci.main:cli:1.509',
#  'org.jenkins-ci.plugins:config-file-provider:952.va_544a_6234b_46',
#  'org.apache.hadoop:hadoop-yarn-server-common:2.8.3',
#  'org.apache.jena:jena-fuseki:2.6.0',
#  'org.apache.hadoop:hadoop-yarn-server-common:2.8.4',
#  'org.jenkins-ci.main:cli:1.504',
#  'org.apache.hadoop:hadoop-yarn-server-common:2.8.1',
#  'io.gitlab.arturbosch.detekt:detekt-core:1.0.0-gradle-rework-beta1',
#  'ca.uhn.hapi.fhir:org.hl7.fhir.r4:5.4.1',
#  'org.jenkins-ci.main:cli:1.505',
#  'org.apache.hadoop:hadoop-yarn-server-common:2.8.2',
#  'io.gitlab.arturbosch.detekt:detekt-core:1.0.0-gradle-rework-beta2',
#  'ca.uhn.hapi.fhir:org.hl7.fhir.r4:5.4.2',
#  'org.jenkins-ci.main:cli:1.506',
#  'io.quarkus:quarkus-undertow:1.0.0.Final',
#  'org.jenkins-ci.main:cli:1.507',
#  'org.apache.hadoop:hadoop-yarn-server-common:2.8.0',
#  'ca.uhn.hapi.fhir:org.hl7.fhir.r4:5.4.0',
#  'org.jenkins-ci.main:cli:1.500',
#  'org.springframework.data:spring-data-mongodb:1.10.18.RELEASE',
#  'org.jenkins-ci.main:cli:1.501',
#  'org.jenkins-ci.main:cli:1.502',
#  'io.gitlab.arturbosch.detekt:detekt-core:1.0.0-gradle-rework-beta3',
#  'org.jenkins-ci.main:cli:1.503',
#  'org.quartz-scheduler:quartz:2.1.0',
#  'org.quartz-scheduler:quartz:2.1.5',
#  'org.graylog2:graylog2-server:4.2.10',
#  'org.quartz-scheduler:quartz:2.1.6',
#  'org.quartz-scheduler:quartz:2.1.7',
#  'org.quartz-scheduler:quartz:2.1.1',
#  'org.quartz-scheduler:quartz:2.1.2',
#  'org.quartz-scheduler:quartz:2.1.3',
#  'org.quartz-scheduler:quartz:2.1.4',
#  'org.wildfly.core:wildfly-server:2.0.2.Final',
#  'com.xuxueli:xxl-job:1.5.1',
#  'com.xuxueli:xxl-job:1.5.2',
#  'com.xuxueli:xxl-job:1.5.0',
#  'org.jenkins-ci.main:cli:1.519',
#  'com.compuware.jenkins:compuware-common-configuration:1.0.9',
#  'com.compuware.jenkins:compuware-common-configuration:1.0.7',
#  'com.compuware.jenkins:compuware-common-configuration:1.0.8',
#  'org.jenkins-ci.main:cli:1.515',
#  'com.compuware.jenkins:compuware-common-configuration:1.0.5',
#  'org.jenkins-ci.main:cli:1.516',
#  'com.compuware.jenkins:compuware-common-configuration:1.0.6',
#  'org.jenkins-ci.main:cli:1.517',
#  'com.compuware.jenkins:compuware-common-configuration:1.0.3',
#  'org.jenkins-ci.main:cli:1.518',
#  'com.compuware.jenkins:compuware-common-configuration:1.0.4',
#  'org.jenkins-ci.main:cli:1.511',
#  'org.jenkins-ci.main:cli:1.512',
#  'com.compuware.jenkins:compuware-common-configuration:1.0.2',
#  'org.jenkins-ci.main:cli:1.513',
#  'org.jenkins-ci.main:cli:1.514',
#  'org.graylog2:graylog2-server:4.2.13',
#  'org.graylog2:graylog2-server:4.2.11',
#  'org.jenkins-ci.main:cli:1.510',
#  'org.graylog2:graylog2-server:4.2.12',
#  'com.guicedee.services:commons-text:1.0.12.4-jre13',
#  'org.apache.tomcat:tomcat:10.0.0',
#  'com.guicedee.services:commons-text:1.0.12.4-jre14',
#  'org.apache.tomcat:tomcat:10.0.2',
#  'com.guicedee.services:commons-text:1.0.12.4-jre12',
#  'org.apache.tomcat:tomcat:10.0.4',
#  'org.apache.tomcat:tomcat:10.0.5',
#  'org.apache.tomcat:tomcat:10.0.6',
#  'org.jenkins-ci.plugins:build-monitor-plugin:1.12+build.201708172343',
#  'org.apache.cxf:cxf-rt-frontend-jaxrs:2.4.9',
#  'com.graphql-java:graphql-java:0.0.0-2022-02-17T08-44-12-981f8408',
#  'ca.uhn.hapi.fhir:org.hl7.fhir.r5:5.4.0',
#  'ca.uhn.hapi.fhir:org.hl7.fhir.r5:5.4.1',
#  'ca.uhn.hapi.fhir:org.hl7.fhir.r5:5.4.2',
#  'ca.uhn.hapi.fhir:org.hl7.fhir.r5:5.4.3',
#  'ca.uhn.hapi.fhir:org.hl7.fhir.r5:5.4.4',
#  'ca.uhn.hapi.fhir:org.hl7.fhir.r5:5.4.5',
#  'org.jenkins-ci.main:cli:1.526',
#  'ca.uhn.hapi.fhir:org.hl7.fhir.r5:5.4.6',
#  'org.jenkins-ci.main:cli:1.527',
#  'ca.uhn.hapi.fhir:org.hl7.fhir.r5:5.4.7',
#  'org.jenkins-ci.main:cli:1.528',
#  'ca.uhn.hapi.fhir:org.hl7.fhir.r5:5.4.8',
#  'org.jenkins-ci.main:cli:1.529',
#  'ca.uhn.hapi.fhir:org.hl7.fhir.r5:5.4.9',
#  'org.jenkins-ci.main:cli:1.522',
#  'org.jenkins-ci.main:cli:1.523',
#  'org.jenkins-ci.main:cli:1.524',
#  'org.springframework:spring-beans:5.0.15.RELEASE',
#  'org.jenkins-ci.main:cli:1.525',
#  'org.jenkins-ci.main:cli:1.520',
#  'io.quarkus:quarkus-vertx-http:2.13.0.CR1',
#  'org.jenkins-ci.main:cli:1.521',
#  'org.eclipse.jetty:jetty-server:7.6.16.v20140903',
#  'org.wso2.carbon.event-processing:org.wso2.carbon.event.processor.core:2.1.20',
#  'org.jboss.resteasy:resteasy-client:3.0.12.Final',
#  'org.wso2.carbon.event-processing:org.wso2.carbon.event.processor.core:2.1.21',
#  'ca.uhn.hapi.fhir:org.hl7.fhir.dstu3:5.3.10',
#  'ca.uhn.hapi.fhir:org.hl7.fhir.dstu3:5.3.11',
#  'ca.uhn.hapi.fhir:org.hl7.fhir.dstu3:5.3.12',
#  'ca.uhn.hapi.fhir:org.hl7.fhir.dstu3:5.3.14',
#  'net.sf.mpxj-for-vb:10.1.0',
#  'org.apache.cxf:cxf-rt-frontend-jaxrs:2.4.1',
#  'org.wso2.carbon.event-processing:org.wso2.carbon.event.processor.core:2.1.28',
#  'org.apache.cxf:cxf-rt-frontend-jaxrs:2.4.2',
#  'org.wso2.carbon.event-processing:org.wso2.carbon.event.processor.core:2.1.29',
#  'org.apache.cxf:cxf-rt-frontend-jaxrs:2.4.3',
#  'org.wso2.carbon.event-processing:org.wso2.carbon.event.processor.core:2.1.26',
#  'org.apache.cxf:cxf-rt-frontend-jaxrs:2.4.4',
#  'org.wso2.carbon.event-processing:org.wso2.carbon.event.processor.core:2.1.27',
#  'org.apache.cxf:cxf-rt-frontend-jaxrs:2.4.5',
#  'org.jenkins-ci.main:cli:1.537',
#  'soap:soap:2.3.1',
#  'org.wso2.carbon.event-processing:org.wso2.carbon.event.processor.core:2.1.24',
#  'org.apache.cxf:cxf-rt-frontend-jaxrs:2.4.6',
#  'org.jenkins-ci.main:cli:1.538',
#  'org.wso2.carbon.event-processing:org.wso2.carbon.event.processor.core:2.1.25',
#  'org.apache.cxf:cxf-rt-frontend-jaxrs:2.4.7',
#  'org.jenkins-ci.main:cli:1.539',
#  'org.wso2.carbon.event-processing:org.wso2.carbon.event.processor.core:2.1.22',
#  'org.apache.cxf:cxf-rt-frontend-jaxrs:2.4.8',
#  'org.wso2.carbon.event-processing:org.wso2.carbon.event.processor.core:2.1.23',
#  'org.jenkins-ci.main:cli:1.533',
#  'org.jboss.xnio:xnio-api:2.0.0.GA',
#  'org.kie.server:kie-server-common:7.1.0.Beta1',
#  'com.datapipe.jenkins.plugins:hashicorp-vault-plugin:2.0.1',
#  'org.jenkins-ci.main:cli:1.534',
#  'org.kie.server:kie-server-common:7.1.0.Beta2',
#  'org.jenkins-ci.main:cli:1.535',
#  'org.glassfish.main.orb:orb-connector:5.0',
#  'org.jenkins-ci.main:cli:1.536',
#  'com.datapipe.jenkins.plugins:hashicorp-vault-plugin:2.0.0',
#  'org.fitnesse:fitnesse:20190224',
#  'org.jenkins-ci.main:cli:1.530',
#  'org.jenkins-ci.main:cli:1.531',
#  'org.apache.cxf:cxf-rt-frontend-jaxrs:2.4.0',
#  'org.jenkins-ci.main:cli:1.532',
#  'io.quarkus.resteasy.reactive:resteasy-reactive-common:1.13.0.CR1',
#  'org.jenkins-ci.main:cli:1.550',
#  'org.keycloak:keycloak-core:1.8.0.Final',
#  'org.infinispan:infinispan-core:7.2.3.Final',
#  'org.apache.tomcat:tomcat-websocket:9.0.0.M10',
#  'io.netty:netty-all:4.1.8.Final',
#  'org.jenkins-ci.main:cli:1.548',
#  'org.eclipse.hono:hono-core:1.1.0-M1',
#  'org.jenkins-ci.main:cli:1.549',
#  'org.eclipse.hono:hono-core:1.1.0-M2',
#  'com.microsoft.commondatamodel:objectmodel:1.0.6',
#  'org.elasticsearch:elasticsearch:5.2.0',
#  'com.microsoft.commondatamodel:objectmodel:1.0.7',
#  'org.elasticsearch:elasticsearch:5.2.1',
#  'org.jenkins-ci.main:cli:1.544',
#  'org.elasticsearch:elasticsearch:5.2.2',
#  'org.jenkins-ci.main:cli:1.545',
#  'org.jenkins-ci.main:cli:1.546',
#  'org.jenkins-ci.main:cli:1.547',
#  'org.jenkins-ci.main:cli:1.540',
#  'org.jenkins-ci.main:cli:1.541',
#  'org.jboss.resteasy:resteasy-client:4.5.10.Final',
#  'org.jenkins-ci.main:cli:1.542',
#  'org.jenkins-ci.main:cli:1.543',
#  'org.fitnesse:fitnesse:20190216',
#  'org.apache.karaf:apache-karaf:4.0.10',
#  'org.jboss.xnio:xnio-nio:3.7.1.Final',
#  'org.jenkins-ci.main:cli:1.560',
#  'org.jenkins-ci.main:cli:1.561',
#  'org.postgresql:postgresql:42.2.15.jre7',
#  'io.quarkus:quarkus-keycloak-authorization:2.7.0.Final',
#  'org.apache.tomcat:tomcat-websocket:9.0.0.M19',
#  'org.postgresql:postgresql:42.2.15.jre6',
#  'org.apache.tomcat:tomcat-websocket:9.0.0.M17',
#  'org.apache.tomcat:tomcat-websocket:9.0.0.M18',
#  'org.apache.tomcat:tomcat-websocket:9.0.0.M15',
#  'org.apache.tomcat:tomcat-websocket:9.0.0.M13',
#  'com.azure:azure-storage-blob:12.0.0-preview.3',
#  'com.azure:azure-storage-blob:12.0.0-preview.4',
#  'org.apache.tomcat:tomcat-websocket:9.0.0.M11',
#  'com.azure:azure-storage-blob:12.0.0-preview.1',
#  'com.azure:azure-storage-blob:12.0.0-preview.2',
#  'org.apache.tomcat:tomcat-websocket:9.0.0.M20',
#  'org.apache.tomcat:tomcat-websocket:9.0.0.M21',
#  'org.xwiki.commons:xwiki-commons:12.7.1',
#  'org.jenkins-ci.main:cli:1.559',
#  'org.jenkins-ci.main:cli:1.555',
#  'org.apache.tomcat:tomcat:10.0.7',
#  'org.jenkins-ci.main:cli:1.556',
#  'org.apache.tomcat:tomcat:10.0.8',
#  'org.jenkins-ci.main:cli:1.557',
#  'org.jenkins-ci.main:cli:1.558',
#  'org.jenkins-ci.main:cli:1.551',
#  'org.fitnesse:fitnesse:20190202',
#  'org.jenkins-ci.main:cli:1.552',
#  'org.jenkins-ci.main:cli:1.553',
#  'org.jenkins-ci.main:cli:1.554',
#  'org.mortbay.jetty:jetty:6.1.0rc0',
#  'org.mortbay.jetty:jetty:6.1.0rc1',
#  'org.jenkins-ci.main:cli:1.570',
#  'io.netty:netty-codec:4.0.12.Final',
#  'org.jenkins-ci.main:cli:1.571',
#  'org.opensearch:opensearch:1.3.13',
#  'org.jenkins-ci.main:cli:1.572',
#  'org.opensearch:opensearch:1.3.11',
#  'io.apiman:apiman-manager-api-rest-impl:2.0.0.Final',
#  'org.opensearch:opensearch:1.3.12',
#  'org.opensearch:opensearch:1.3.10',
#  'com.github.seancfoley:ipaddress:4.0.0',
#  'org.apache.struts:struts2-struts1-plugin:2.3.33',
#  'org.apache.struts:struts2-struts1-plugin:2.3.34',
#  'org.apache.tomcat:tomcat-websocket:9.0.0.M26',
#  'org.apache.struts:struts2-struts1-plugin:2.3.35',
#  'org.apache.tomcat:tomcat-websocket:9.0.0.M27',
#  'org.apache.struts:struts2-struts1-plugin:2.3.36',
#  'org.apache.struts:struts2-struts1-plugin:2.3.37',
#  'org.apache.tomcat:tomcat-websocket:9.0.0.M25',
#  'org.xwiki.commons:xwiki-commons-xml:14.3-rc-1',
#  'org.apache.tomcat:tomcat-websocket:9.0.0.M22',
#  'io.netty:netty:3.5.12.Final',
#  'org.infinispan:infinispan-core:7.2.2.Final',
#  'org.jenkins-ci.main:cli:1.566',
#  'org.jenkins-ci.main:cli:1.567',
#  'org.jenkins-ci.main:cli:1.568',
#  'org.jenkins-ci.main:cli:1.569',
#  'org.jenkins-ci.main:cli:1.562',
#  'org.jenkins-ci.main:cli:1.563',
#  'org.jenkins-ci.main:cli:1.564',
#  'org.jenkins-ci.main:cli:1.565',
#  'org.jenkins-ci.main:cli:1.580',
#  'org.jenkins-ci.main:cli:1.581',
#  'org.springframework:spring-expression:5.0.0.RELEASE',
#  'org.jenkins-ci.plugins:google-compute-engine:4.1.0',
#  'org.jenkins-ci.main:cli:1.582',
#  'org.jenkins-ci.plugins:google-compute-engine:4.1.1',
#  'org.jenkins-ci.main:cli:1.583',
#  'org.apache.struts:struts2-struts1-plugin:2.3.24',
#  'org.apache.james:james-server:3.0-M1',
#  'org.apache.james:james-server:3.0-M2',
#  'org.apache.struts:struts2-struts1-plugin:2.3.28',
#  'org.apache.struts:struts2-struts1-plugin:2.3.29',
#  'org.springframework.security:spring-security-core:3.2.3.RELEASE',
#  'org.apache.struts:struts2-struts1-plugin:2.3.30',
#  'org.apache.struts:struts2-struts1-plugin:2.3.31',
#  'org.apache.struts:struts2-struts1-plugin:2.3.32',
#  'org.jenkins-ci.main:cli:1.577',
#  'org.jenkins-ci.main:cli:1.578',
#  'org.jenkins-ci.main:cli:1.579',
#  'org.jenkins-ci.main:cli:1.573',
#  'org.jenkins-ci.main:cli:1.574',
#  'org.jenkins-ci.main:cli:1.575',
#  'org.jenkins-ci.main:cli:1.576',
#  'io.quarkus.resteasy.reactive:resteasy-reactive:3.0.0.Beta1',
#  'org.jenkins-ci.main:cli:1.470',
#  'org.jvnet.hudson.main:hudson-core:1.249',
#  'org.wso2.carbon.commons:org.wso2.carbon.ntask.core:4.6.57',
#  'org.jenkins-ci.main:cli:1.471',
#  'org.wso2.carbon.commons:org.wso2.carbon.ntask.core:4.6.58',
#  'org.jenkins-ci.main:cli:1.472',
#  'org.wso2.carbon.commons:org.wso2.carbon.ntask.core:4.6.55',
#  'org.jenkins-ci.main:cli:1.473',
#  'org.wso2.carbon.commons:org.wso2.carbon.ntask.core:4.6.56',
#  'org.jvnet.hudson.main:hudson-core:1.245',
#  'org.jvnet.hudson.main:hudson-core:1.247',
#  'org.wso2.carbon.commons:org.wso2.carbon.ntask.core:4.6.59',
#  'org.jvnet.hudson.main:hudson-core:1.248',
#  'org.jvnet.hudson.main:hudson-core:1.241',
#  'org.apache.struts:struts2-struts1-plugin:2.3.12',
#  'google-protobuf:3.9.0.rc.1',
#  'org.jvnet.hudson.main:hudson-core:1.242',
#  'org.wso2.carbon.commons:org.wso2.carbon.ntask.core:4.6.50',
#  'org.jenkins-ci.plugins.workflow:workflow-support:1.15',
#  'org.jvnet.hudson.main:hudson-core:1.243',
#  'org.apache.struts:struts2-struts1-plugin:2.3.14',
#  'org.jvnet.hudson.main:hudson-core:1.244',
#  'org.apache.struts:struts2-struts1-plugin:2.3.15',
#  'org.jenkins-ci.plugins.workflow:workflow-support:1.13',
#  'org.wildfly.bom:wildfly:22.0.0.Final',
#  'org.wso2.carbon.commons:org.wso2.carbon.ntask.core:4.6.53',
#  'org.apache.struts:struts2-struts1-plugin:2.3.16',
#  'org.jenkins-ci.plugins.workflow:workflow-support:1.14',
#  'org.wso2.carbon.commons:org.wso2.carbon.ntask.core:4.6.54',
#  'org.jenkins-ci.plugins.workflow:workflow-support:1.11',
#  'org.wso2.carbon.commons:org.wso2.carbon.ntask.core:4.6.51',
#  'org.jenkins-ci.plugins.workflow:workflow-support:1.12',
#  'org.eclipse.jetty:jetty-http:9.2.19.v20160908',
#  'org.jvnet.hudson.main:hudson-core:1.240',
#  'org.wso2.carbon.commons:org.wso2.carbon.ntask.core:4.6.52',
#  'com.amazonaws:aws-encryption-sdk-java:1.6.2',
#  'net.sf.mpxj:mpxj:8.3.3',
#  'org.quartz-scheduler:quartz:1.8.1',
#  'com.typesafe.play:play-ws_2.12:2.6.0-RC1',
#  'org.jenkins-ci.plugins.workflow:workflow-support:1.10',
#  'net.sf.mpxj:mpxj:8.3.4',
#  'org.quartz-scheduler:quartz:1.8.2',
#  'com.pubnub:pubnub:4.0.0-beta1',
#  'com.typesafe.play:play-ws_2.12:2.6.0-RC2',
#  'net.sf.mpxj:mpxj:8.3.5',
#  'org.quartz-scheduler:quartz:1.8.0',
#  'io.quarkus:quarkus-resteasy-reactive-common:3.4.0.CR1',
#  'org.apache.solr:solr-parent:3.6.0',
#  'org.apache.struts:struts2-struts1-plugin:2.3.20',
#  'com.amazonaws:aws-encryption-sdk-java:1.6.0',
#  'org.apache.solr:solr-parent:3.6.1',
#  'org.jenkins-ci.plugins:testng-plugin:700.va_ea_5873a_3399',
#  'com.amazonaws:aws-encryption-sdk-java:1.6.1',
#  'org.jenkins-ci.main:cli:1.467',
#  'org.apache.solr:solr-parent:3.6.2',
#  'org.elasticsearch:elasticsearch:5.4.0',
#  'org.jenkins-ci.main:cli:1.468',
#  'org.elasticsearch:elasticsearch:5.4.1',
#  'org.jenkins-ci.main:cli:1.469',
#  'org.skyscreamer:nevado-jms:1.0.0-Beta1',
#  'org.elasticsearch:elasticsearch:5.4.2',
#  'org.skyscreamer:nevado-jms:1.0.0-Beta2',
#  'org.elasticsearch:elasticsearch:5.4.3',
#  'org.jenkins-ci.main:cli:1.463',
#  'org.quartz-scheduler:quartz:1.8.5',
#  'org.jenkins-ci.main:cli:1.464',
#  'net.sf.mpxj:mpxj:8.3.0',
#  'org.quartz-scheduler:quartz:1.8.6',
#  'org.jenkins-ci.main:cli:1.465',
#  'net.sf.mpxj:mpxj:8.3.1',
#  'org.quartz-scheduler:quartz:1.8.3',
#  'org.jenkins-ci.main:cli:1.466',
#  'net.sf.mpxj:mpxj:8.3.2',
#  'org.quartz-scheduler:quartz:1.8.4',
#  'org.jenkins-ci.main:cli:1.481',
#  'org.jenkins-ci.main:cli:1.482',
#  'org.xwiki.rendering:xwiki-rendering-syntax-html:6.1-milestone-1',
#  'org.jenkins-ci.main:cli:1.483',
#  'org.jenkins-ci.main:cli:1.484',
#  'com.netflix.hollow:hollow:4.8.0',
#  'org.jvnet.hudson.main:hudson-core:1.256',
#  'org.infinispan:infinispan-core:6.0.0.Beta1',
#  'org.apache.syncope:syncope-core:1.2.0',
#  'org.jvnet.hudson.main:hudson-core:1.257',
#  'org.jvnet.hudson.main:hudson-core:1.258',
#  'org.jenkins-ci.main:cli:1.480',
#  'org.jvnet.hudson.main:hudson-core:1.259',
#  'org.apache.syncope:syncope-core:1.2.3',
#  'org.jvnet.hudson.main:hudson-core:1.252',
#  'com.graphql-java:graphql-java:0.0.0-2023-10-30T22-58-00-448780b',
#  'org.wso2.carbon.commons:org.wso2.carbon.ntask.core:4.6.60',
#  'org.apache.syncope:syncope-core:1.2.4',
#  'org.jvnet.hudson.main:hudson-core:1.253',
#  'org.wso2.carbon.commons:org.wso2.carbon.ntask.core:4.6.61',
#  'org.apache.syncope:syncope-core:1.2.1',
#  'org.jvnet.hudson.main:hudson-core:1.254',
#  'org.apache.syncope:syncope-core:1.2.2',
#  'org.jvnet.hudson.main:hudson-core:1.255',
#  'org.apache.syncope:syncope-core:1.2.7',
#  'com.netflix.hollow:hollow:4.8.1',
#  'org.wso2.carbon.commons:org.wso2.carbon.ntask.core:4.6.64',
#  'org.apache.syncope:syncope-core:1.2.8',
#  'com.netflix.hollow:hollow:4.8.2',
#  'org.wso2.carbon.commons:org.wso2.carbon.ntask.core:4.6.65',
#  'org.apache.syncope:syncope-core:1.2.5',
#  'org.jvnet.hudson.main:hudson-core:1.250',
#  'com.netflix.hollow:hollow:4.8.3',
#  'org.wso2.carbon.commons:org.wso2.carbon.ntask.core:4.6.62',
#  'org.xwiki.rendering:xwiki-rendering-syntax-html:6.1-milestone-2',
#  'org.apache.syncope:syncope-core:1.2.6',
#  'org.jvnet.hudson.main:hudson-core:1.251',
#  'com.netflix.hollow:hollow:4.8.4',
#  'org.wso2.carbon.commons:org.wso2.carbon.ntask.core:4.6.63',
#  'org.apache.syncope:syncope-core:1.2.9',
#  'org.xwiki.commons:xwiki-commons:3.4-milestone-1',
#  'org.jenkins-ci.main:cli:1.478',
#  'org.jenkins-ci.main:cli:1.479',
#  'org.infinispan:infinispan-core:6.0.0.Beta2',
#  'org.xwiki.commons:xwiki-commons-velocity:6.0-rc-1',
#  'org.jenkins-ci.main:cli:1.474',
#  'org.jenkins-ci.main:cli:1.475',
#  'org.jenkins-ci.main:cli:1.476',
#  'org.jenkins-ci.main:cli:1.477',
#  'org.jenkins-ci.main:cli:1.492',
#  'org.jvnet.hudson.main:hudson-core:1.227',
#  'org.jenkins-ci.main:cli:1.493',
#  'org.jvnet.hudson.main:hudson-core:1.228',
#  'org.noear:solon:1.2.10.1',
#  'org.jenkins-ci.main:cli:1.494',
#  'org.jvnet.hudson.main:hudson-core:1.229',
#  'org.jenkins-ci.main:cli:1.495',
#  'net.sourceforge.htmlunit:neko-htmlunit:2.46.0',
#  'org.jvnet.hudson.main:hudson-core:1.223',
#  'org.jvnet.hudson.main:hudson-core:1.224',
#  'org.jenkins-ci.main:cli:1.490',
#  'org.jvnet.hudson.main:hudson-core:1.225',
#  'org.jenkins-ci.main:cli:1.491',
#  'org.jvnet.hudson.main:hudson-core:1.226',
#  'org.jvnet.hudson.main:hudson-core:1.220',
#  'org.springframework:spring-web:4.3.14.RELEASE',
#  'org.jvnet.hudson.main:hudson-core:1.221',
#  'org.jvnet.hudson.main:hudson-core:1.222',
#  'org.jboss.xnio:xnio-api:3.8.8.Final',
#  'org.jboss.as:jboss-as-server:7.1.0.CR1b',
#  'org.jboss.resteasy:resteasy-bom:4.0.0.CR3',
#  'com.googlecode.owasp-java-html-sanitizer:owasp-java-html-sanitizer:20191001.1',
#  'org.jenkins-ci.main:cli:1.489',
#  'com.guicedee.services:commons-text:1.0.1.1-jre8',
#  'org.jenkins-ci.main:cli:1.485',
#  'org.apache.cxf:cxf:3.1.10',
#  ...]
